# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\SMART\\Desktop\\pract\\TF CHALLENGE\\day3\\diet.csv")
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8       1        25      3     1.0  0.75  34.384843

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.129870   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.215823   22.342523   0.832524   0.150477   0.232716
# ...

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#yellow lines indicates missing information in the data

# %%
df = df.sort_values(['rating'],ascending=False).reset_index(drop=True)
plt.figure(figsize=(20,20))
sns.barplot(x=df["rating"],y=df["name"])
plt.xlabel("Product Name",fontsize=25)
plt.ylabel("Rating",fontsize=25)
plt.title("product rating",fontsize=15)
plt.show()

# %%
df['rating'].plot.hist(bins=20,figsize=(10,5))
plt.xlabel("Rating")
plt.ylabel("numbers")
plt.show()

# %%
df['rating'].describe()
# Out:
# count    77.000000
# mean     42.665705
# std      14.047289
# min      18.042851
# 25%      33.174094
# 50%      40.400208
# 75%      50.828392
# max      93.704912
# Name: rating, dtype: float64

# %%
f, axes = plt.subplots(1,2, figsize=(15, 5))
sns.countplot(x="mfr", data=df, ax=axes[0], palette="magma")
sns.countplot(x="type", data=df, ax=axes[1], palette="hot")

# %%
top=train.nlargest(15,'rating')
top
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 3                100% Bran   N    C        70        4    1     130   10.0
# 4           Shredded Wheat   N    C        80        2    0       0    3.0
# 5   Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 7              Puffed Rice   Q    C        50        1    0       0    0.0
# 9                 All-Bran   K    C        70        4    1     260    9.0
# 11     Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# 16               Special K   K    C       110        6    0     230    1.0
# 17       Grape Nuts Flakes   P    C       100        3    1     140    3.0
# 20                Cheerios   G    C       110        6    2     290    2.0
# 22      Quaker Oat Squares   Q    C       100        4    1     135    2.0
# 23               Bran Chex   R    C        90        2    1     200    4.0
# ...

# %%
from matplotlib import style
style.use('ggplot')

top.plot(x='mfr',y='rating',kind='bar',linewidth=1,color='g')
plt.ylabel('rating')

plt.grid()
plt.show()

# %%
df.drop(['name'], axis = 1, inplace = True)

# %%
df
# Out:
#    mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0    N    C        70        4    1     130   10.0    5.0       6     280
# 1    Q    C       120        3    5      15    2.0    8.0       8     135
# 2    K    C        70        4    1     260    9.0    7.0       5     320
# 3    K    C        50        4    0     140   14.0    8.0       0     330
# 4    R    C       110        2    2     200    1.0   14.0       8       1
# ..  ..  ...       ...      ...  ...     ...    ...    ...     ...     ...
# 72   G    C       110        2    1     250    0.0   21.0       3      60
# 73   G    C       110        1    1     140    0.0   13.0      12      25
# 74   R    C       100        3    1     230    3.0   17.0       3     115
# 75   G    C       100        3    1     200    3.0   17.0       3     110
# 76   G    C       110        2    1     200    1.0   16.0       8      60
#
#     vitamins  shelf  weight  cups     rating
# ...

# %%
#shuffle

# %%
from sklearn.utils import shuffle
data = shuffle(train)
data.dropna(inplace=True)

# %%
df.head()
# Out:
#   mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0   N    C        70        4    1     130   10.0    5.0       6     280
# 1   Q    C       120        3    5      15    2.0    8.0       8     135
# 2   K    C        70        4    1     260    9.0    7.0       5     320
# 3   K    C        50        4    0     140   14.0    8.0       0     330
# 4   R    C       110        2    2     200    1.0   14.0       8       1
#
#    vitamins  shelf  weight  cups     rating
# 0        25      3     1.0  0.33  68.402973
# 1         0      3     1.0  1.00  33.983679
# 2        25      3     1.0  0.33  59.425505
# 3        25      3     1.0  0.50  93.704912
# 4        25      3     1.0  0.75  34.384843

# %%
#shuffle the data

# %%
from sklearn.utils import shuffle
df = shuffle(df)
df.dropna(inplace=True)

# %%
list(df.mfr.unique())
# Out:
# ['Q', 'N', 'K', 'P', 'G', 'R', 'A']

# %%
list(df.type.unique())
# Out:
# ['C', 'H']

# %%
df.mfr.replace(dict(zip(list(df.mfr.unique()), range(7))), inplace=True)
df.type.replace(dict(zip(list(df.type.unique()), range(2))), inplace=True)

# %%
df
# Out:
#     mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 54    0     0        50        1    0       0    0.0   13.0       0      15
# 64    1     0        90        3    0       0    4.0   19.0       0     140
# 53    2     0       100        3    0     320    1.0   20.0       3      45
# 39    2     0       140        3    1     170    2.0   20.0       9      95
# 30    3     0       100        2    0      45    0.0   11.0      15      40
# ..  ...   ...       ...      ...  ...     ...    ...    ...     ...     ...
# 12    4     0       120        1    3     210    0.0   13.0       9      45
# 14    4     0       110        1    1     180    0.0   12.0      13      55
# 20    1     1       100        3    0      80    1.0   21.0       0       1
# 41    0     0       100        4    2     150    2.0   12.0       6      95
# 26    2     0       100        3    0       0    3.0   14.0       7     100
#
#     vitamins  shelf  weight  cups     rating
# ...

# %%
df.drop(['name'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-298-643562502a06> in <module>
# ----> 1 df.drop(['name'], axis = 1, inplace = True)
#
# c:\users\smart\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# c:\users\smart\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.head()
# Out:
#     mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 54    0     0        50        1    0       0    0.0   13.0       0      15
# 64    1     0        90        3    0       0    4.0   19.0       0     140
# 53    2     0       100        3    0     320    1.0   20.0       3      45
# 39    2     0       140        3    1     170    2.0   20.0       9      95
# 30    3     0       100        2    0      45    0.0   11.0      15      40
#
#     vitamins  shelf  weight  cups     rating
# 54         0      3     0.5  1.00  60.756112
# 64         0      1     1.0  0.67  74.472949
# 53       100      3     1.0  1.00  41.503540
# 39       100      3     1.3  0.75  36.471512
# 30        25      1     1.0  0.88  35.252444

# %%
df.columns
# Out:
# Index(['mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo',
#        'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating'],
#       dtype='object')

# %%
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=11)
# from sklearn.linear_model import LinearRegression
# lm=LinearRegression()
# lm.fit(X_train, y_train)
# lm.score(X_test,y_test)
# plt.scatter(y_test,predi)

# %%
# from sklearn.linear_model import LinearRegression
# lm=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.25)

# %%
def x_y_split(df):
    x = df.iloc[:,:-1]
    y = df.iloc[:,-1]
    return np.array(x, dtype=float), np.array(y, dtype=float)

# %%
x_train, y_train = x_y_split(train)
x_test, y_test = x_y_split(test)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(1024, activation = 'relu'),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_65 (Dense)             multiple                  3840
# _________________________________________________________________
# dense_66 (Dense)             multiple                  32896
# _________________________________________________________________
# dense_67 (Dense)             multiple                  132096
# _________________________________________________________________
# dense_68 (Dense)             multiple                  262400
# _________________________________________________________________
# dense_69 (Dense)             multiple                  257
# ...
# Total params: 431,489
# Trainable params: 431,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.SGD(),
    metrics = ['acc']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs = 50
)
# Out:
# Epoch 1/50
# 57/57 [==============================] - 0s 368us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 2/50
# 57/57 [==============================] - 0s 281us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 3/50
# 57/57 [==============================] - 0s 263us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 4/50
# 57/57 [==============================] - 0s 281us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 5/50
# 57/57 [==============================] - 0s 281us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 6/50
# 57/57 [==============================] - 0s 281us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 7/50
# 57/57 [==============================] - 0s 281us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 8/50
# 57/57 [==============================] - 0s 298us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 9/50
# 57/57 [==============================] - 0s 281us/sample - loss: 5.2142e-06 - acc: 0.0000e+00
# Epoch 10/50
# ...

# %%
import sklearn
regressor = sklearn.linear_model.Ridge()
regressor.fit(x_train, y_train)
regressor.score(x_test, y_test)
# Out:
# 0.9997096358199741

# %%
regressor = sklearn.linear_model.Lasso()
regressor.fit(x_train, y_train)
regressor.score(x_test, y_test)
# Out:
# 0.9600322877043931

# %%
regressor = sklearn.linear_model.LassoLars(alpha = 0.0001)
regressor.fit(x_train, y_train)
regressor.score(x_test, y_test)
# Out:
# 0.9999984615502514

# %%
# from sklearn import metrics
# print('mse',metrics.mean_absolute_error(y_test,predi))
# print('mse',metrics.mean_squared_error(y_test,predi))
# np.sqrt(metrics.mean_squared_error(y_test,predi))
