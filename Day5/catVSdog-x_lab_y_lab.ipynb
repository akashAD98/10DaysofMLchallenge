# %%
import cv2
import numpy as np
import  os
import matplotlib.pyplot as plt
import seaborn as sns

#mypath=("H:\\DATA SETS\\catsVSdog\\train")
#file_name=[f for f in listdir(mypath) if isfile(join(mypath,f))]
#print(str(len(file_name))+'iamg lod')

# %%
import cv2
import numpy as np
import  os
import matplotlib.pyplot as plt
import seaborn as sns


DATADIR="H:/DATA SETS/catsVSdog"
CATEGORIES=['cat','dog']

for category in CATEGORIES:
    path = os.path.join(DATADIR,category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array,cmap='gray')
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# (374, 500)

# %%
IMG_SIZE=50 #reshape the image
new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
plt.imshow(new_array,cmap='gray')
plt.show()

# %%
training_data=[]
def  create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR,category)
        class_num=CATEGORIES.index(category) #indexing 0 & 1 for cat and dog
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
            except exception as e:
                pass
create_training_data()

# %%
print(len(training_data))
# Out:
# 25000

# %%
import random
random.shuffle(training_data)

# %%
for sample in training_data[:10]
    print(sample)
